# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## Introduction to Matplotlib

# %% [markdown]
# ## Why MatPlotlib?
#
# - Built on numpy arrays (and python)
# - Integrates directly with Pandas
# - Can create basic or advanced plots

# %%
plt.plot();
plt.show(); # this is manditory

# %%
plt.plot([1, 2, 3, 4]);
plt.show();

# %%
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]
plt.plot(x, y);
plt.show();

# %%
# 1st method
fig = plt.figure() # creates a figure
ax = fig.add_subplot() #adds some axes
plt.show();

# %%
# 2nd method
fig = plt.figure() # creates a figure
ax = fig.add_axes([1, 1, 1, 1]);
ax.plot(x, y) # adds some data
plt.show();

# %%
# 3rd method (recommended)
fig, ax = plt.subplots();
ax.plot(x, [50, 100, 200, 250]) # add some data
plt.show();
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %% [markdown]
# ## Anatomy of a Matplotlib Plot Figure (plot, visulization)

# %% [markdown]
# ## Matplotlib example Workfrlow

# %%
# 0. import matplotpib and gt it ready for plotting in Jupyter
import matplotlib.pyplot as plt

# 1. 
x = [1, 2, 3, 4]
y = [11, 22, 33, 55]

# 2. Setup plot
fig, ax = plt.subplots(figsize=(10, 10))

# 3. Plot the data
ax.plot(x, y)

# 4. Customize plot
ax.set(title="simple Plot", 
       xlabel="xaxis",
       ylabel="yaxis")
# 5. Save & show (you save the whole figure)
fig.savefig("/images/sample-plot.png")
plt.show();
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[40], line 19
#      15 ax.set(title="simple Plot",
#      16        xlabel="xaxis",
#      17        ylabel="yaxis")
#      18 # 5. Save & show (you save the whole figure)
# ---> 19 fig.savefig("/images/sample-plot.png")
#      20 plt.show()
#
# File ~/sample_project/env/lib/python3.12/site-packages/matplotlib/figure.py:3395, in Figure.savefig(self, fname, transparent, **kwargs)
#    3393     for ax in self.axes:
#    3394         _recursively_make_axes_transparent(stack, ax)
# -> 3395 self.canvas.print_figure(fname, **kwargs)
#
# File ~/sample_project/env/lib/python3.12/site-packages/matplotlib/backend_bases.py:2204, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2200 try:
# ...
